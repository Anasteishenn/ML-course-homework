# %% [markdown]
# Датасет: House Prices - Advanced Regression Techniques
# Источник: https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques

# %% [markdown]
# 1) Быстрый обзор данных (Pandas)

# %%
train_df=pd.read_csv('data/train.train_csv')
